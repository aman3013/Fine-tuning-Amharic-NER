# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from nltk.tokenize import word_tokenize

# %%
sys.path.append('../scripts')

# %%
df = pd.read_csv('../data/tokenized_cleaned_data.csv')

# %%
df
# Out:
#      Unnamed: 0          Channel Title     Channel Username    ID  \
# 0             0    ኩሩ/kuru/ 🇪🇹 wear ®️            @kuruwear  1378
# 1             1    ኩሩ/kuru/ 🇪🇹 wear ®️            @kuruwear  1377
# 2             2    ኩሩ/kuru/ 🇪🇹 wear ®️            @kuruwear  1376
# 3             3    ኩሩ/kuru/ 🇪🇹 wear ®️            @kuruwear  1375
# 4             4    ኩሩ/kuru/ 🇪🇹 wear ®️            @kuruwear  1374
# ..          ...                    ...                  ...   ...
# 455         691  emartzon sportswear 👕  @emartzonsportswear  2008
# 456         692  emartzon sportswear 👕  @emartzonsportswear  1992
# 457         693  emartzon sportswear 👕  @emartzonsportswear  1982
# 458         694  emartzon sportswear 👕  @emartzonsportswear  1966
# 459         695  emartzon sportswear 👕  @emartzonsportswear  1948
#
#                                                Message  \
# 0    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 1    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 2    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 3    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2800 ...
# 4    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# ..                                                 ...
# 455  ሰላም የ emartzon sportswear ቤተሰቦች PL መጀመርን ምክንያት...
# 456  #መቷል_available_now‼\n#ኦሪጅናል_ማሊያ\nOriginal Umbr...
# 457  #መቷል_available_now‼\n#ኦሪጅናል_ማሊያ\nOriginal Adid...
# 458  #መቷል_available_now‼\n#ኦሪጅናል_ማሊያ\nOriginal umbr...
# 459  #መቷል_available_now ‼\n#ኦሪጅናል_ማሊያ\nOriginal Adi...
#
#                           Date                           Media Path  \
# 0    2024-09-21 06:16:43+00:00            photos\@kuruwear_1378.jpg
# 1    2024-09-21 06:16:35+00:00            photos\@kuruwear_1377.jpg
# 2    2024-09-21 06:16:22+00:00            photos\@kuruwear_1376.jpg
# 3    2024-09-21 06:16:04+00:00            photos\@kuruwear_1375.jpg
# 4    2024-09-14 07:11:18+00:00            photos\@kuruwear_1374.jpg
# ..                         ...                                  ...
# 455  2023-08-10 13:36:16+00:00  photos\@emartzonsportswear_2008.jpg
# 456  2023-07-27 08:48:25+00:00  photos\@emartzonsportswear_1992.jpg
# 457  2023-07-22 05:22:58+00:00  photos\@emartzonsportswear_1982.jpg
# 458  2023-07-06 08:25:10+00:00  photos\@emartzonsportswear_1966.jpg
# 459  2023-06-10 06:18:59+00:00  photos\@emartzonsportswear_1948.jpg
#
#                                        Cleaned_Message  \
# 0    100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
# 1    100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
# 2    100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
# 3    100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2800 ብር ብቻ 091...
# 4    100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
# ..                                                 ...
# 455  ሰላም የ ቤተሰቦች መጀመርን ምክንያት በማድረግ ለምትጫወቱ ከታች ባለው በ...
# 456  #መቷል_available_now‼ #ኦሪጅናል_ማሊያ #Man_United 199...
# 457  #መቷል_available_now‼ #ኦሪጅናል_ማሊያ #Man_United 23/...
# 458  #መቷል_available_now‼ #ኦሪጅናል_ማሊያ #Man_United 199...
# 459  #መቷል_available_now ‼ #ኦሪጅናል_ማሊያ # :,,,, ዋጋ: 1,...
#
#                                         tokenized_text
# 0    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 1    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 2    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 3    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2800 ...
# 4    100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# ..                                                 ...
# 455  ሰላም የ emartzon sportswear ቤተሰቦች PL መጀመርን ምክንያት...
# 456  #መቷል_available_now‼\n#ኦሪጅናል_ማሊያ\nOriginal Umbr...
# 457  #መቷል_available_now‼\n#ኦሪጅናል_ማሊያ\nOriginal Adid...
# 458  #መቷል_available_now‼\n#ኦሪጅናል_ማሊያ\nOriginal umbr...
# 459  #መቷል_available_now ‼\n#ኦሪጅናል_ማሊያ\nOriginal Adi...
#
# [460 rows x 9 columns]

# %%
messages = df['Message'].tolist()

# %%
import pandas as pd
import re

def label_message_utf8_with_birr(message):
    if pd.isna(message):  # Check if the message is NaN
        return "O"  # Return a default value or you can choose to return an empty string

    # Split the message at the first occurrence of '\n'
    if '\n' in message:
        first_line, remaining_message = message.split('\n', 1)
    else:
        first_line, remaining_message = message, ""
    
    labeled_tokens = []
    
    # Tokenize the first line
    first_line_tokens = re.findall(r'\S+', first_line)
    
    # Label the first token as B-PRODUCT and the rest as I-PRODUCT
    if first_line_tokens:
        labeled_tokens.append(f"{first_line_tokens[0]} B-PRODUCT")  # First token as B-PRODUCT
        for token in first_line_tokens[1:]:
            labeled_tokens.append(f"{token} I-PRODUCT")  # Remaining tokens as I-PRODUCT
    
    # Process the remaining message normally
    if remaining_message:
        lines = remaining_message.split('\n')
        for line in lines:
            tokens = re.findall(r'\S+', line)  # Tokenize each line
            
            for token in tokens:
                # Check if token is a price
                if re.match(r'^\d+(\.\d{1,2})?$', token) or 'ETB' in token or 'ዋጋ' in token or '$' in token or 'ብር' in token:
                    labeled_tokens.append(f"{token} B-PRICE")  # Label as B-PRICE
                # Check if token could be a location
                elif token in ['Addis Ababa', 'ቦሌ', '22ማዞሪያ', 'አበጋዝ ሆቴል', 'ቁጥር 44', 'ቁጥር 210', 'ሜክሲኮ']:
                    labeled_tokens.append(f"{token} B-LOC")  # Start of location entity
                elif token in ['ኦሎምፒያ', 'ጌቱ', 'ኮሜርሻል', 'አጠገብ', 'ራዩማ', 'ህንፃ']:  # Identify products
                    labeled_tokens.append(f"{token} B-PRODUCT")  # Start of product entity
                else:
                    labeled_tokens.append(f"{token} O")  # Outside any entities

    return "\n".join(labeled_tokens)  # Return as a single string

# Apply the updated function to the non-null messages
df['Labeled_Message'] = df['Message'].apply(label_message_utf8_with_birr)

# Display the updated DataFrame
df.head()
# Out:
#    Unnamed: 0        Channel Title Channel Username    ID  \
# 0           0  ኩሩ/kuru/ 🇪🇹 wear ®️        @kuruwear  1378
# 1           1  ኩሩ/kuru/ 🇪🇹 wear ®️        @kuruwear  1377
# 2           2  ኩሩ/kuru/ 🇪🇹 wear ®️        @kuruwear  1376
# 3           3  ኩሩ/kuru/ 🇪🇹 wear ®️        @kuruwear  1375
# 4           4  ኩሩ/kuru/ 🇪🇹 wear ®️        @kuruwear  1374
#
#                                              Message  \
# 0  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 1  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 2  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 3  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2800 ...
# 4  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
#
#                         Date                 Media Path  \
# 0  2024-09-21 06:16:43+00:00  photos\@kuruwear_1378.jpg
# 1  2024-09-21 06:16:35+00:00  photos\@kuruwear_1377.jpg
# 2  2024-09-21 06:16:22+00:00  photos\@kuruwear_1376.jpg
# 3  2024-09-21 06:16:04+00:00  photos\@kuruwear_1375.jpg
# 4  2024-09-14 07:11:18+00:00  photos\@kuruwear_1374.jpg
#
#                                      Cleaned_Message  \
# 0  100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
# 1  100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
# 2  100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
# 3  100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2800 ብር ብቻ 091...
# 4  100% ንፁ ቆዳ የተሰሩ ጫማዎች የሀገራችን ምርት 2400 ብር ብቻ 091...
#
#                                       tokenized_text  \
# 0  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 1  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 2  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
# 3  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2800 ...
# 4  100% ንፁ ቆዳ የተሰሩ ጫማዎች\n የሀገራችን ምርት \n     2400 ...
#
#                                      Labeled_Message
# 0  100% B-PRODUCT\nንፁ I-PRODUCT\nቆዳ I-PRODUCT\nየተ...
# 1  100% B-PRODUCT\nንፁ I-PRODUCT\nቆዳ I-PRODUCT\nየተ...
# 2  100% B-PRODUCT\nንፁ I-PRODUCT\nቆዳ I-PRODUCT\nየተ...
# 3  100% B-PRODUCT\nንፁ I-PRODUCT\nቆዳ I-PRODUCT\nየተ...
# 4  100% B-PRODUCT\nንፁ I-PRODUCT\nቆዳ I-PRODUCT\nየተ...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = 'labeled_telegram_product_price_location.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in df.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")
